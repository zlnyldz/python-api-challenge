# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ea449d73-223e-441c-968d-39e6acaed3ab" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"95d96081-860f-4f0b-95ac-1d38edd9140b":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"3d7512f71c3448a2b5fc0e76d74ab57b","client_comm_id":"22029b04a55745b1992b21e6bf66879f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"95d96081-860f-4f0b-95ac-1d38edd9140b","roots":{"p1002":"ea449d73-223e-441c-968d-39e6acaed3ab"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0           thompson  55.7435  -97.8558     -3.91        93
# 1        1             saipan  15.1355  145.7010     27.03        91
# 2        2        west island -12.1568   96.8225     26.99        83
# 3        3  port-aux-francais -49.3500   70.2167      4.86        90
# 4        4               lebu -37.6167  -73.6500     14.26        67
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        1.54      CA  1731337385
# 1          20        0.89      MP  1731337374
# 2         100        5.14      CC  1731337312
# 3          91        6.46      TF  1731337388
# 4          20        4.25      CL  1731337389

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
import hvplot.pandas

# Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame.
# The size of the point should be the humidity in each city.

# Ensure correct column names and data types
# Double-check the column names in your city_data_df DataFrame (Latitude, Longitude, Humidity)
# Make sure they are in the correct format (numeric values)

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    x='Lng',  # Replace 'Lng' with the correct column name for longitude if different
    y='Lat',  # Replace 'Lat' with the correct column name for latitude if different
    size='Humidity',  # Replace with the correct column name for humidity
    color='City',  # Optionally color by city
    title="City Humidity Map",
    geo=True,  # Enable geographic plotting
    tiles='OSM',  # You can change this to another tile if desired, like 'CartoDB positron'
    size_max=30,  # Adjust the max size of the points for better visibility
    colorbar=True,  # Show colorbar if you want to see the color scale
    width=800,  # Set the width of the map
    height=600  # Set the height of the map
)

# Display the map
map_plot
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1015'>
#   <div id="b741ff2f-3e2c-40d7-a369-0bfac4caf00d" data-root-id="p1015" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"78b839e6-29cf-4737-8593-5cb4f48d9814":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1015"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1016","attributes":{"plot_id":"p1015","comm_id":"f8940fa4efd34692a547bb5b32c1f6a2","client_comm_id":"f8ace56773944d69a7f8df95ef14a080"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"78b839e6-29cf-4737-8593-5cb4f48d9814","roots":{"p1015":"b741ff2f-3e2c-40d7-a369-0bfac4caf00d"},"root_ids":["p1015"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# WARNING:param.main: size_max option not found for points plot with bokeh; similar options include: ['size']
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
import pandas as pd
import requests
import hvplot.pandas  # Import for interactive plotting
from api_keys import geoapify_key  # Assuming your API key is stored here

# Load the weather data CSV file created in the previous part of the project
city_data_df = pd.read_csv("output_data/cities.csv")

# Display a few rows to understand the structure of the data
print(city_data_df.head())

# Plot the cities on an interactive map with points sized by humidity
map_plot = city_data_df.hvplot.points(
    "Lng",  # Longitude for the x-axis
    "Lat",  # Latitude for the y-axis
    geo=True,  # Enables a geographic map
    size="Humidity",  # Size of points based on humidity
    scale=1,
    color="City",  # Assigns a unique color to each city
    alpha=0.5,  # Sets transparency for overlapping points
    tiles="OSM",  # Background map tiles
    frame_width=700,
    frame_height=500
)

# Display the map
map_plot

# Define ideal weather conditions
ideal_temp_min = 21  # Minimum temperature in Celsius
ideal_temp_max = 27  # Maximum temperature in Celsius
max_wind_speed = 4.5  # Maximum acceptable wind speed (m/s)
cloudiness_required = 0  # Only clear skies (0% cloudiness)

# Filter cities based on the ideal conditions
ideal_weather_cities = city_data_df.loc[
    (city_data_df["Max Temp"] > ideal_temp_min) &
    (city_data_df["Max Temp"] < ideal_temp_max) &
    (city_data_df["Wind Speed"] < max_wind_speed) &
    (city_data_df["Cloudiness"] == cloudiness_required)
].dropna()

# Display filtered cities
print(ideal_weather_cities.head())

# Create hotel_df with relevant columns
hotel_df = ideal_weather_cities[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column where hotel names will be stored
hotel_df["Hotel Name"] = ""

# Define the search radius in meters (10 km)
search_radius = 10000  # 10 km

# Start searching for hotels near each city
print("Starting hotel search...")

# Loop through each row in the DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Define the parameters for the API request
    params = {
        "categories": "accommodation.hotel",
        "filter": f"circle:{longitude},{latitude},{search_radius}",
        "bias": f"proximity:{longitude},{latitude}",
        "limit": 1,  # Get only the closest hotel
        "apiKey": geoapify_key
    }
    
    # Make a request to the Geoapify AP
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1141'>
#   <div id="a724828a-6b02-456f-be03-ce5b57f8784e" data-root-id="p1141" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3f6e25c5-1025-4933-83dc-4ea53b5cbdeb":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1141"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1142","attributes":{"plot_id":"p1141","comm_id":"ea1b6bbb1b0f46589c5e20864a5d2bd3","client_comm_id":"7beab312801a4091b09acd4973b1d9e5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"3f6e25c5-1025-4933-83dc-4ea53b5cbdeb","roots":{"p1141":"a724828a-6b02-456f-be03-ce5b57f8784e"},"root_ids":["p1141"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0           thompson  55.7435  -97.8558     -3.91        93
# 1        1             saipan  15.1355  145.7010     27.03        91
# 2        2        west island -12.1568   96.8225     26.99        83
# 3        3  port-aux-francais -49.3500   70.2167      4.86        90
# 4        4               lebu -37.6167  -73.6500     14.26        67
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        1.54      CA  1731337385
# 1          20        0.89      MP  1731337374
# 2         100        5.14      CC  1731337312
# 3          91        6.46      TF  1731337388
# 4          20        4.25      CL  1731337389
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 45        45                 isangel -19.5500  169.2667     22.69        88
# 110      110  hawaiian paradise park  19.5933 -154.9731     21.61        73
# 205      205             port isabel  26.0734  -97.2086     25.57        91
# 231      231             tamanrasset  22.7850    5.5228     24.95        18
# 232      232                 pakokku  21.3333   95.1000     25.02        76
#
#      Cloudiness  Wind Speed Country        Date
# 45            0        3.99      VU  1731337437
# 110           0        3.09      US  1731337513
# 205           0        2.57      US  1731337631
# 231           0        1.54      DZ  1731337662
# 232           0        0.74      MM  1731337664
# Starting hotel search...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Step 2: Create a DataFrame for the Northern Hemisphere (latitude >= 0)
# First, we need to ensure the 'Lat' column exists and is numeric.
if 'Lat' in city_data_df.columns:
    # Filter the cities with latitude greater than or equal to 0 (Northern Hemisphere)
    northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
    
    # Display sample data (first few rows)
    print("Sample data from Northern Hemisphere:")
    print(northern_hemi_df.head())  # Display the first few rows of the filtered data
else:
    print("'Lat' column is missing in the DataFrame.")
# Out:
# Sample data from Northern Hemisphere:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        thompson  55.7435  -97.8558     -3.91        93         100
# 1        1          saipan  15.1355  145.7010     27.03        91          20
# 6        6  island harbour  50.7240   -1.2758     12.79        66         100
# 7        7           utrik  11.2278  169.8474     28.17        80          43
# 8        8       jamestown  42.0970  -79.2353     10.57        83         100
#
#    Wind Speed Country        Date
# 0        1.54      CA  1731337385
# 1        0.89      MP  1731337374
# 6        1.79      GB  1731337392
# 7        7.81      MH  1731337393
# 8        7.20      US  1731337394

# %%
# Check the columns in filtered_cities to ensure you are using the correct ones
print(filtered_cities.shape)  # This will show the number of rows and columns
print(filtered_cities.head())  # This will display the first few rows
print(filtered_cities.columns)  # This will display the column names

# Ensure that the columns you are trying to access are present and spelled correctly
# If there are different column names for 'Latitude' and 'Longitude', update accordingly.
# For example, if 'Latitude' is 'Lat' and 'Longitude' is 'Lng', change the following line.

# Use the correct column names based on the output of filtered_cities.columns
hotel_df = filtered_cities[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name,"
# Out:
# (77, 10)
#     City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 32       32    arraial do cabo -22.9661  -42.0278     26.98        50
# 53       53              crane  31.3974 -102.3501     15.69        41
# 63       63           beinamar   8.6698   15.3813     33.50        22
# 79       79  capilla del monte -30.8609  -64.5251     19.49        33
# 83       83          iranshahr  27.2025   60.6848     28.19        18
#
#     Cloudiness  Wind Speed Country        Date
# 32           0        7.72      BR  1731337423
# 53           6        2.17      US  1731337446
# 63           8        2.71      TD  1731337457
# 79          54        1.34      AR  1731337475
# 83           0        2.06      IR  1731337480
# Index(['City_ID', 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
import requests
import pandas as pd

# Ensure that geoapify_key is correctly imported
from api_keys import geoapify_key  # Ensure that the geoapify_key is available in api_keys.py

# Set parameters to search for a hotel
radius = 10000  # Set search radius (in meters, 10 km)
params = {
    "categories": "accommodation.hotel",  # Search for hotels
    "limit": 20,  # Get only one closest hotel
    "apiKey": geoapify_key  # Add your API key (make sure geoapify_key is imported from api_keys)
}

# Print a message to follow up the hotel search
print("Starting hotel search...")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Print the coordinates for debugging
    print(f"Searching for hotels near: Latitude {latitude}, Longitude {longitude}")

    # Update the params dictionary with the current city's latitude and longitude
    params["filter"] = f"circle:{longitude},{latitude},{radius}"  # Set the radius for the search
    params["bias"] = f"proximity:{longitude},{latitude}"  # Set the bias to the city's location

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results for each city
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display the updated DataFrame with hotel names
hotel_df
# Out:
# Starting hotel search...
# Searching for hotels near: Latitude -22.9661, Longitude -42.0278
# arraial do cabo - nearest hotel: No hotel found
# Searching for hotels near: Latitude 31.3974, Longitude -102.3501
# crane - nearest hotel: No hotel found
# Searching for hotels near: Latitude 8.6698, Longitude 15.3813
# beinamar - nearest hotel: No hotel found
# Searching for hotels near: Latitude -30.8609, Longitude -64.5251
# capilla del monte - nearest hotel: Hospedaje Galicia
# Searching for hotels near: Latitude 27.2025, Longitude 60.6848
# iranshahr - nearest hotel: هتل قصِر
# Searching for hotels near: Latitude 4.6167, Longitude -61.1333
# santa elena de uairen - nearest hotel: Posada Villa Fairmont
# Searching for hotels near: Latitude -26.4833, Longitude 17.15
# bethanie - nearest hotel: No hotel found
# Searching for hotels near: Latitude 22.6783, Longitude -3.9836
# taoudenni - nearest hotel: No hotel found
# Searching for hotels near: Latitude 38.4167, Longitude 77.2406
# shache - nearest hotel: 莎车新盛宾馆
# Searching for hotels near: Latitude -28.9361, Longitude -51.5494
# veranopolis - nearest hotel: Hotel Princesa Dos Vales
# Searching for hotels near: Latitude -35.1667, Longitude 147.3833
# lake albert - nearest hotel: The Astor
# Searching for hotels near: Latitude -14.2426, Longitude 31.3253
# petauke - nearest hotel: Chimwemwe Lodge
# Searching for hotels near: Latitude -15.1165, Longitude 39.2666
# nampula - nearest hotel: Hotel Lurio
# Searching for hotels near: Latitude 31.5874, Longitude 44.6602
# nahiyat ash shinafiyah - nearest hotel: No hotel found
# Searching for hotels near: Latitude -17.7833, Longitude -57.7667
# puerto quijarro - nearest hotel: No hotel found
# Searching for hotels near: Latitude 30.4062, Longitude 19.5739
# al burayqah - nearest hotel: فندق ماس ليبيا
# Searching for hotels near: Latitude 17.0187, Longitude 8.0168
# alaghsas - nearest hotel: Hôtel Zagado
# Searching for hotels near: Latitude 22.785, Longitude 5.5228
# tamanrasset - nearest hotel: فندق الأمان
# Searching for hotels near: Latitude -33.6227, Longitude -64.5971
# coronel moldes - nearest hotel: No hotel found
# Searching for hotels near: Latitude 15.451, Longitude 36.4
# kassala - nearest hotel: No hotel found
# Searching for hotels near: Latitude 29.1081, Longitude 21.2869
# awjilah - nearest hotel: No hotel found
# Searching for hotels near: Latitude 28.3492, Longitude 28.8659
# al bawiti - nearest hotel: Old Oasis Hotel
# Searching for hotels near: Latitude 25.35, Longitude 72.6167
# jalor - nearest hotel: No hotel found
# Searching for hotels near: Latitude 13.95, Longitude 20.55
# goz beida - nearest hotel: No hotel found
# Searching for hotels near: Latitude -4.2917, Longitude -44.7917
# bacabal - nearest hotel: Hotel Ibis
# Searching for hotels near: Latitude 9.2667, Longitude -9.0167
# kerouane - nearest hotel: No hotel found
# Searching for hotels near: Latitude 25.9155, Longitude 13.9184
# murzuq - nearest hotel: فندق باريس - مرزق
# Searching for hotels near: Latitude 18.5564, Longitude -11.4271
# tidjikja - nearest hotel: No hotel found
# Searching for hotels near: Latitude -5.5375, Longitude -35.8197
# joao camara - nearest hotel: No hotel found
# Searching for hotels near: Latitude -34.8957, Longitude -60.0167
# chivilcoy - nearest hotel: Falcone
# Searching for hotels near: Latitude 10.3999, Longitude 5.4695
# kontagora - nearest hotel: No hotel found
# Searching for hotels near: Latitude 27.5, Longitude 13.2667
# idri - nearest hotel: No hotel found
# Searching for hotels near: Latitude -25.2144, Longitude -59.8585
# ibarreta - nearest hotel: Hotel Plaza
# Searching for hotels near: Latitude 22.4333, Longitude 41.7583
# al muwayh - nearest hotel: فندق ومطعم الموية
# Searching for hotels near: Latitude 20.4607, Longitude 45.5779
# as sulayyil - nearest hotel: No hotel found
# Searching for hotels near: Latitude 33.7456, Longitude -117.8678
# santa ana - nearest hotel: Holiday Inn Express
# Searching for hotels near: Latitude -18.0607, Longitude 13.84
# opuwo - nearest hotel: Ohakane Lodge
# Searching for hotels near: Latitude -20.7333, Longitude 139.5
# mount isa - nearest hotel: Ibis Styles
# Searching for hotels near: Latitude -38.7187, Longitude -61.2873
# coronel dorrego - nearest hotel: Hotel América
# Searching for hotels near: Latitude 50.8552, Longitude 0.5729
# hastings - nearest hotel: White Rock Hotel
# Searching for hotels near: Latitude 40.3469, Longitude 14.9966
# agropoli - nearest hotel: limone apartments
# Searching for hotels near: Latitude 26.4833, Longitude 8.4667
# illizi - nearest hotel: بوناقة
# Searching for hotels near: Latitude -17.2333, Longitude -67.9167
# patacamaya - nearest hotel: Hostal Viña del Mar
# Searching for hotels near: Latitude 8.6761, Longitude 16.566
# bebedja - nearest hotel: No hotel found
# Searching for hotels near: Latitude 27.3104, Longitude 30.97
# manfalut - nearest hotel: No hotel found
# Searching for hotels near: Latitude -7.8825, Longitude -40.0817
# ouricuri - nearest hotel: Hotel França
# Searching for hotels near: Latitude -45.5882, Longitude -69.07
# sarmiento - nearest hotel: Ismar
# Searching for hotels near: Latitude 34.6667, Longitude 61.0667
# kafir qala - nearest hotel: No hotel found
# Searching for hotels near: Latitude 10.6162, Longitude 47.368
# ceerigaabo - nearest hotel: Sanaag Hotel
# Searching for hotels near: Latitude -14.8864, Longitude -70.5889
# ayaviri - nearest hotel: Hotel San Francisco
# Searching for hotels near: Latitude 35.2799, Longitude 62.3438
# serhetabat - nearest hotel: No hotel found
# Searching for hotels near: Latitude -33.4569, Longitude -70.6483
# santiago - nearest hotel: apart arturo prat
# Searching for hotels near: Latitude 18.4411, Longitude 1.4078
# kidal - nearest hotel: No hotel found
# Searching for hotels near: Latitude 19.75, Longitude 10.25
# agadez - nearest hotel: No hotel found
# Searching for hotels near: Latitude -7.5119, Longitude -39.7242
# exu - nearest hotel: No hotel found
# Searching for hotels near: Latitude -16.3667, Longitude -60.95
# san ignacio de velasco - nearest hotel: Hotel Caparu
# Searching for hotels near: Latitude 8.0777, Longitude 22.4007
# ouadda - nearest hotel: No hotel found
# Searching for hotels near: Latitude 24.05, Longitude 77.4
# leteri - nearest hotel: No hotel found
# Searching for hotels near: Latitude -20.7377, Longitude 116.8463
# karratha - nearest hotel: Karratha International Hotel
# Searching for hotels near: Latitude 11.65, Longitude 7.2333
# bardai - nearest hotel: No hotel found
# Searching for hotels near: Latitude 16.7095, Longitude 33.3565
# el matama - nearest hotel: الكوثر
# Searching for hotels near: Latitude 21.65, Longitude 74.7
# pansemal - nearest hotel: No hotel found
# Searching for hotels near: Latitude 23.3908, Longitude 57.4244
# rustaq - nearest hotel: Shoumoukh Tourist Hotel
# Searching for hotels near: Latitude -23.9631, Longitude -46.3919
# sao vicente - nearest hotel: Pousada Vitória
# Searching for hotels near: Latitude 9.5221, Longitude 45.5336
# burao - nearest hotel: Liiban hotel burco ( ENG:Shibiin )
# Searching for hotels near: Latitude 16.7735, Longitude -3.0074
# timbuktu - nearest hotel: Hotel La Maison
# Searching for hotels near: Latitude -5.1833, Longitude -68.9
# jutai - nearest hotel: No hotel found
# Searching for hotels near: Latitude 9.6225, Longitude 3.9481
# kaiama - nearest hotel: No hotel found
# Searching for hotels near: Latitude 5.6, Longitude 14.0833
# betare oya - nearest hotel: No hotel found
# Searching for hotels near: Latitude -14.8167, Longitude -66.85
# san borja - nearest hotel: No hotel found
# Searching for hotels near: Latitude 29.4963, Longitude 60.8629
# zahedan - nearest hotel: هتل صالح;بانک ملی
# Searching for hotels near: Latitude -30.36, Longitude -66.314
# chamical - nearest hotel: No hotel found
# Searching for hotels near: Latitude 5.3435, Longitude 6.6532
# omoku - nearest hotel: Royal Fortress Hotels
# Searching for hotels near: Latitude 36.5872, Longitude 36.1735
# iskenderun - nearest hotel: aykut palace
# Searching for hotels near: Latitude 20.5022, Longitude -10.0711
# adrar - nearest hotel: No hotel found
# Searching for hotels near: Latitude 29.9776, Longitude 48.4741
# al faw - nearest hotel: No hotel found
# Searching for hotels near: Latitude -16.92, Longitude 35.262
# nsanje - nearest hotel: No hotel found
#                   City Country      Lat       Lng  Humidity  \
# 32     arraial do cabo      BR -22.9661  -42.0278        50
# 53               crane      US  31.3974 -102.3501        41
# 63            beinamar      TD   8.6698   15.3813        22
# 79   capilla del monte      AR -30.8609  -64.5251        33
# 83           iranshahr      IR  27.2025   60.6848        18
# ..                 ...     ...      ...       ...       ...
# 542              omoku      NG   5.3435    6.6532        33
# 553         iskenderun      TR  36.5872   36.1735        48
# 554              adrar      MR  20.5022  -10.0711         9
# 569             al faw      IQ  29.9776   48.4741        35
# 575             nsanje      MW -16.9200   35.2620        35
#
#                 Hotel Name
# 32          No hotel found
# 53          No hotel found
# 63          No hotel found
# 79       Hospedaje Galicia
# 83                هتل قصِر
# ..                     ...
# 542  Royal Fortress Hotels
# 553           aykut palace
# 554         No hotel found
# 569         No hotel found
# 575         No hotel found
#
# [77 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
# Configure the map plot
Map_city = hotel_df.hvplot.points(
    x='Lng',  # Replace 'Lng' with the correct column name for longitude if different
    y='Lat',  # Replace 'Lat' with the correct column name for latitude if different
    size='Humidity',  # Replace with the correct column name for humidity
    color='City',  # Optionally color by city
    title="city_picture Map",
    geo=True,  # Enable geographic plotting
    tiles='OSM',  # You can change this to another tile if desired, like 'CartoDB positron'
    size_max=30,  # Adjust the max size of the points for better visibility
    colorbar=True,  # Show colorbar if you want to see the color scale
    width=800,  # Set the width of the map
    height=600 , # Set the height of the map
    hover_cols=["Hotel_Name","Country"]
)
# Display the map
Map_city
# Out:
# WARNING:param.main: size_max option not found for points plot with bokeh; similar options include: ['size']
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)
